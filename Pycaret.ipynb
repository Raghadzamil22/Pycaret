# %%
! pip install pandas
! pip install streamlit
! pip install pycaret
# Out:
# Requirement already satisfied: pandas in /Users/raghad/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: streamlit in /Users/raghad/anaconda3/lib/python3.11/site-packages (1.33.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: packaging<25,>=16.8 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.4)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/raghad/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Requirement already satisfied: pycaret in /Users/raghad/anaconda3/lib/python3.11/site-packages (3.3.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: cloudpickle in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.2.1)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.12.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: ipython>=5.5.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (8.0.4)
# Requirement already satisfied: jinja2>=3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: matplotlib<3.8.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: numba>=0.55.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.57.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.24.4)
# Requirement already satisfied: pandas<2.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: plotly>=5.14.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (5.21.0)
# Requirement already satisfied: pmdarima>=2.0.4 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pyod>=1.1.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: requests>=2.27.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (2.31.0)
# Requirement already satisfied: schemdraw==0.15 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.15)
# Requirement already satisfied: scikit-learn>1.4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: sktime==0.26.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: tbats>=1.1.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: xxhash in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (1.5)
# Requirement already satisfied: wurlitzer in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: packaging in /Users/raghad/anaconda3/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (24.0)
# Requirement already satisfied: scikit-base<0.8.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from sktime==0.26.0->pycaret) (0.7.7)
# Requirement already satisfied: patsy>=0.5.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from imbalanced-learn>=0.12.0->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.11.0)
# Requirement already satisfied: backcall in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: appnope in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: fastjsonschema in /Users/raghad/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/raghad/anaconda3/lib/python3.11/site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from numba>=0.55.0->pycaret) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas<2.2.0->pycaret) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pandas<2.2.0->pycaret) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from plotly>=5.14.0->pycaret) (8.2.2)
# Requirement already satisfied: dash>=2.9.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.16.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.1)
# Requirement already satisfied: tsdownsample>=0.1.3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (3.0.10)
# Requirement already satisfied: urllib3 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pmdarima>=2.0.4->pycaret) (69.2.0)
# Requirement already satisfied: six in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pyod>=1.1.3->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from requests>=2.27.1->pycaret) (2023.7.22)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.3)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.9.0)
# Requirement already satisfied: retrying in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in /Users/raghad/anaconda3/lib/python3.11/site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.4.9)
# Requirement already satisfied: pyzmq>=17 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/raghad/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: executing in /Users/raghad/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in /Users/raghad/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/raghad/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in /Users/raghad/anaconda3/lib/python3.11/site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: entrypoints in /Users/raghad/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)

# %%
import streamlit as st
import pandas as pd
from pycaret.classification import *
from pycaret.regression import *

# %%
def main():
    st.title("ProjectyCaret ")

    # Upload file
    uploaded_file = st.file_uploader("Upload your CSV file", type=['csv'])
    
    if uploaded_file is not None:
        # Load data
        data = pd.read_csv(uploaded_file)
        
        # Allow user to drop columns
        st.subheader("Data Preview")
        st.write(data.head())
        
        columns_to_drop = st.multiselect("Select columns to drop", data.columns)
        if columns_to_drop:
            data.drop(columns=columns_to_drop, inplace=True)
        
        # EDA
        perform_eda = st.checkbox("Perform Exploratory Data Analysis (EDA)")
        if perform_eda:
            selected_columns = st.multiselect("Select columns for EDA", data.columns)
            if selected_columns:
                st.write(data[selected_columns].describe())
        
        # Handle missing values
        handle_missing = st.radio("How to handle missing values?", ('Drop rows', 'Impute'))
        if handle_missing == 'Drop rows':
            data.dropna(inplace=True)
        elif handle_missing == 'Impute':
            # Perform imputation based on user preference
            pass  # Placeholder for imputation code
        
        # Encode categorical data
        encode_categorical = st.radio("How to encode categorical data?", ('One Hot Encoding', 'Label Encoding'))
        if encode_categorical == 'One Hot Encoding':
            data = pd.get_dummies(data)
        elif encode_categorical == 'Label Encoding':
            # Perform label encoding based on user preference
            pass  # Placeholder for label encoding code
        
        # Choose X and y variables
        X = data.drop(columns=['target_variable'], axis=1)  # Assuming target variable is known
        y = data['target_variable']
        
        # Detect task type
        task_type = 'classification' if len(y.unique()) <= 2 else 'regression'
        
        # Train models
        st.subheader("Training Models")
        if task_type == 'classification':
            setup(data, target='target_variable')
            best_model = compare_models()
        elif task_type == 'regression':
            setup(data, target='target_variable')
            best_model = compare_models()
        
        st.subheader("Best Model")
        st.write(best_model)

if __name__ == "__main__":
    main()
